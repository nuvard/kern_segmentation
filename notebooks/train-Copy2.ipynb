# %%
# !pip install wandb
# Out:
# Requirement already satisfied: wandb in /usr/local/lib/python3.6/dist-packages (0.8.16)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (5.6.7)
# Requirement already satisfied: Click>=7.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (7.0)
# Requirement already satisfied: shortuuid>=0.5.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (0.5.0)
# Requirement already satisfied: subprocess32>=3.5.3 in /usr/local/lib/python3.6/dist-packages (from wandb) (3.5.4)
# Requirement already satisfied: watchdog>=0.8.3 in /usr/local/lib/python3.6/dist-packages (from wandb) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from wandb) (2.8.1)
# Requirement already satisfied: GitPython>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (3.0.5)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: sentry-sdk>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (0.13.4)
# Requirement already satisfied: nvidia-ml-py3>=7.352.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (7.352.0)
# Requirement already satisfied: configparser>=3.8.1 in /usr/local/lib/python3.6/dist-packages (from wandb) (4.0.2)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (1.13.0)
# Requirement already satisfied: gql>=0.1.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (0.1.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (2.22.0)
# Requirement already satisfied: argh>=0.24.1 in /usr/local/lib/python3.6/dist-packages (from watchdog>=0.8.3->wandb) (0.26.2)
# Requirement already satisfied: pathtools>=0.1.1 in /usr/local/lib/python3.6/dist-packages (from watchdog>=0.8.3->wandb) (0.1.2)
# Requirement already satisfied: PyYAML>=3.10 in /usr/lib/python3/dist-packages (from watchdog>=0.8.3->wandb) (3.12)
# Requirement already satisfied: gitdb2>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from GitPython>=1.0.0->wandb) (2.0.6)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from sentry-sdk>=0.4.0->wandb) (2019.9.11)
# Requirement already satisfied: urllib3>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from sentry-sdk>=0.4.0->wandb) (1.25.7)
# Requirement already satisfied: promise>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from gql>=0.1.0->wandb) (2.2.1)
# Requirement already satisfied: graphql-core>=0.5.0 in /usr/local/lib/python3.6/dist-packages (from gql>=0.1.0->wandb) (2.2.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->wandb) (2.8)
# Requirement already satisfied: smmap2>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from gitdb2>=2.0.0->GitPython>=1.0.0->wandb) (2.0.5)
# Requirement already satisfied: rx<3,>=1.6 in /usr/local/lib/python3.6/dist-packages (from graphql-core>=0.5.0->gql>=0.1.0->wandb) (1.6.1)

# %%
import wandb

# %%
wandb.login()
# Out:
# wandb: ERROR Not authenticated.  Copy a key from https://app.wandb.ai/authorize
# API Key: ········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# !pip install numba
# Out:
# Collecting numba
#   Downloading https://files.pythonhosted.org/packages/53/34/22b6c2ded558976b5367be01b851ae679a0d1ba994de002d54afe84187b5/numba-0.46.0-cp36-cp36m-manylinux1_x86_64.whl (3.6MB)
#      |████████████████████████████████| 3.6MB 3.3MB/s eta 0:00:01
# Collecting llvmlite>=0.30.0dev0
#   Downloading https://files.pythonhosted.org/packages/b3/93/924788871a889ead1c115ba2d43e67932a8865d38fdb179505c99e4bb575/llvmlite-0.30.0-cp36-cp36m-manylinux1_x86_64.whl (20.2MB)
#      |████████████████████████████████| 20.2MB 40.4MB/s eta 0:00:01
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from numba) (1.17.4)
# Installing collected packages: llvmlite, numba
# Successfully installed llvmlite-0.30.0 numba-0.46.0

# %%
# !pip install efficientnet-pytorch
# Out:
# Collecting efficientnet-pytorch
#   Downloading https://files.pythonhosted.org/packages/82/18/1c4d61eea11b78235ce270a528e099b19af2f1026aadf45e9c645cd75e2f/efficientnet_pytorch-0.5.1.tar.gz
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from efficientnet-pytorch) (1.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch->efficientnet-pytorch) (1.17.4)
# Building wheels for collected packages: efficientnet-pytorch
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.5.1-cp36-none-any.whl size=11768 sha256=d3222de0df95c4b5fc1196c17e672ff847064283bdc3a3c625c1cd3972ea2d53
#   Stored in directory: /root/.cache/pip/wheels/52/0c/8e/58d91f29f0f8cbb45231a145312939a5423dc82c61cc731361
# Successfully built efficientnet-pytorch
# Installing collected packages: efficientnet-pytorch
# Successfully installed efficientnet-pytorch-0.5.1

# %%
# !python -W ignore ../src/train.py --help
# Out:
# usage: train.py [-h] [--lr LR] [--batch_size BATCH_SIZE]
#                 [--image_size IMAGE_SIZE] [--path PATH] [--tags TAGS]
#                 [--epochs EPOCHS] [--num_classes NUM_CLASSES] [--type TYPE]
#                 [--base BASE] [--wandb WANDB] [--inp_size INP_SIZE] [--b1 B1]
#                 [--b2 B2] [--wd WD]
#
# Train and test loop! Default model: resnet18. NAME =
# TAGS_BASE_TYPE_LR_NUM_CLASSES.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --lr LR               Set up learning rate, default: 1e-3
#   --batch_size BATCH_SIZE
#                         Set up batch size, default: 64
#   --image_size IMAGE_SIZE
#                         Set up image size, default: 128 (for rn18)
#   --path PATH           Set up working dir, default: /project/
#   --tags TAGS           Make model name individual
#   --epochs EPOCHS       Set up num of epochs, default: 100
#   --num_classes NUM_CLASSES
#                         Set up num of classes, default: 6 (oil)
#   --type TYPE           Log type of learning, default: fine-tune (ft)
#   --base BASE           Log type of base model, default: resnet18
#   --wandb WANDB         Log to wandb, default: True
#   --inp_size INP_SIZE   FC layer input size, default:1280
#   --b1 B1               Beta 1, default: 0.9
#   --b2 B2               Beta 2, default: 0.999
#   --wd WD               Weight decay, default: 1e-2

# %%
# !python -W ignore ../src/train_multilabel.py --tags "5#att#squeeze#0.65#tr2" --base "mixnet_s" --image_size 224 --lr 1e-3 --epochs 500 \
--batch_size 32 --wandb 0 --path /project/ --num_classes 3 --treshold 0.5 --inp_size 1536
# Out:
# cuda
# Using device: cuda
# True
# Tesla V100-SXM2-16GB
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB
# ==> Preparing data
# ==> Preparing model
# Using cache found in /root/.cache/torch/hub/rwightman_gen-efficientnet-pytorch_master
# Using cache found in /root/.cache/torch/hub/rwightman_gen-efficientnet-pytorch_master
# GenEfficientNet(
#   (conv_stem): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (act1): ReLU(inplace=True)
#   (blocks): Sequential(
#     (0): Sequential(
#       (0): DepthwiseSeparableConv(
#         (conv_dw): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#         (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (se): Identity()
#         (conv_pw): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): Identity()
#       )
#     )
#     (1): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): MixedConv2d(
#           (0): Conv2d(8, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(8, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (conv_dw): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#         (bn2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (se): Identity()
#         (conv_pwl): MixedConv2d(
#           (0): Conv2d(48, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(48, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): InvertedResidual(
#         (conv_pw): MixedConv2d(
#           (0): Conv2d(12, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(12, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (conv_dw): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#         (bn2): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (se): Identity()
#         (conv_pwl): MixedConv2d(
#           (0): Conv2d(36, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(36, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SwishJit()
#         (conv_dw): MixedConv2d(
#           (0): Conv2d(48, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=48, bias=False)
#           (1): Conv2d(48, 48, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=48, bias=False)
#           (2): Conv2d(48, 48, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), groups=48, bias=False)
#         )
#         (bn2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SwishJit()
#         (se): SqueezeExcite(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (conv_reduce): Conv2d(144, 12, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SwishJit()
#           (conv_expand): Conv2d(12, 144, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pwl): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): InvertedResidual(
#         (conv_pw): MixedConv2d(
#           (0): Conv2d(20, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(20, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SwishJit()
#         (conv_dw): MixedConv2d(
#           (0): Conv2d(120, 120, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=120, bias=False)
#           (1): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#         )
#         (bn2): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SwishJit()
#         (se): SqueezeExcite(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (conv_reduce): Conv2d(240, 20, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SwishJit()
#           (conv_expand): Conv2d(20, 240, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pwl): MixedConv2d(
#           (0): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn3): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): InvertedResidual(
#         (conv_pw): MixedConv2d(
#           (0): Conv2d(20, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(20, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SwishJit()
#         (conv_dw): MixedConv2d(
#           (0): Conv2d(120, 120, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=120, bias=False)
#           (1): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#         )
#         (bn2): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SwishJit()
#         (se): SqueezeExcite(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (conv_reduce): Conv2d(240, 20, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SwishJit()
#           (conv_expand): Conv2d(20, 240, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pwl): MixedConv2d(
#           (0): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn3): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): InvertedResidual(
#         (conv_pw): MixedConv2d(
#           (0): Conv2d(20, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(20, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SwishJit()
#         (conv_dw): MixedConv2d(
#           (0): Conv2d(120, 120, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=120, bias=False)
#           (1): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#         )
#         (bn2): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SwishJit()
#         (se): SqueezeExcite(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (conv_reduce): Conv2d(240, 20, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SwishJit()
#           (conv_expand): Conv2d(20, 240, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pwl): MixedConv2d(
#           (0): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(120, 20, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn3): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SwishJit()
#         (conv_dw): MixedConv2d(
#           (0): Conv2d(80, 80, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=80, bias=False)
#           (1): Conv2d(80, 80, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=80, bias=False)
#           (2): Conv2d(80, 80, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), groups=80, bias=False)
#         )
#         (bn2): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SwishJit()
#         (se): SqueezeExcite(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (conv_reduce): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SwishJit()
#           (conv_expand): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pwl): MixedConv2d(
#           (0): Conv2d(120, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(120, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn3): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SwishJit()
#         (conv_dw): MixedConv2d(
#           (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=240, bias=False)
#           (1): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#         )
#         (bn2): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SwishJit()
#         (se): SqueezeExcite(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (conv_reduce): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SwishJit()
#           (conv_expand): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pwl): MixedConv2d(
#           (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn3): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SwishJit()
#         (conv_dw): MixedConv2d(
#           (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=240, bias=False)
#           (1): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#         )
#         (bn2): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SwishJit()
#         (se): SqueezeExcite(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (conv_reduce): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SwishJit()
#           (conv_expand): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pwl): MixedConv2d(
#           (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn3): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): MixedConv2d(
#           (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SwishJit()
#         (conv_dw): MixedConv2d(
#           (0): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=160, bias=False)
#           (1): Conv2d(160, 160, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=160, bias=False)
#           (2): Conv2d(160, 160, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=160, bias=False)
#         )
#         (bn2): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SwishJit()
#         (se): SqueezeExcite(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (conv_reduce): Conv2d(480, 40, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SwishJit()
#           (conv_expand): Conv2d(40, 480, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pwl): MixedConv2d(
#           (0): Conv2d(240, 60, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(240, 60, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn3): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): InvertedResidual(
#         (conv_pw): MixedConv2d(
#           (0): Conv2d(60, 180, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(60, 180, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn1): BatchNorm2d(360, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SwishJit()
#         (conv_dw): MixedConv2d(
#           (0): Conv2d(90, 90, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=90, bias=False)
#           (1): Conv2d(90, 90, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=90, bias=False)
#           (2): Conv2d(90, 90, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=90, bias=False)
#           (3): Conv2d(90, 90, kernel_size=(9, 9), stride=(1, 1), padding=(4, 4), groups=90, bias=False)
#         )
#         (bn2): BatchNorm2d(360, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SwishJit()
#         (se): SqueezeExcite(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (conv_reduce): Conv2d(360, 60, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SwishJit()
#           (conv_expand): Conv2d(60, 360, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pwl): MixedConv2d(
#           (0): Conv2d(180, 60, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(180, 60, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn3): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): InvertedResidual(
#         (conv_pw): MixedConv2d(
#           (0): Conv2d(60, 180, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(60, 180, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn1): BatchNorm2d(360, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SwishJit()
#         (conv_dw): MixedConv2d(
#           (0): Conv2d(90, 90, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=90, bias=False)
#           (1): Conv2d(90, 90, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=90, bias=False)
#           (2): Conv2d(90, 90, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=90, bias=False)
#           (3): Conv2d(90, 90, kernel_size=(9, 9), stride=(1, 1), padding=(4, 4), groups=90, bias=False)
#         )
#         (bn2): BatchNorm2d(360, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SwishJit()
#         (se): SqueezeExcite(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (conv_reduce): Conv2d(360, 60, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SwishJit()
#           (conv_expand): Conv2d(60, 360, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pwl): MixedConv2d(
#           (0): Conv2d(180, 60, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(180, 60, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn3): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SwishJit()
#         (conv_dw): MixedConv2d(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#           (1): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#           (2): Conv2d(144, 144, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), groups=144, bias=False)
#           (3): Conv2d(144, 144, kernel_size=(9, 9), stride=(2, 2), padding=(4, 4), groups=144, bias=False)
#           (4): Conv2d(144, 144, kernel_size=(11, 11), stride=(2, 2), padding=(5, 5), groups=144, bias=False)
#         )
#         (bn2): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SwishJit()
#         (se): SqueezeExcite(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (conv_reduce): Conv2d(720, 60, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SwishJit()
#           (conv_expand): Conv2d(60, 720, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pwl): Conv2d(720, 200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SwishJit()
#         (conv_dw): MixedConv2d(
#           (0): Conv2d(300, 300, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=300, bias=False)
#           (1): Conv2d(300, 300, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=300, bias=False)
#           (2): Conv2d(300, 300, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=300, bias=False)
#           (3): Conv2d(300, 300, kernel_size=(9, 9), stride=(1, 1), padding=(4, 4), groups=300, bias=False)
#         )
#         (bn2): BatchNorm2d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SwishJit()
#         (se): SqueezeExcite(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (conv_reduce): Conv2d(1200, 100, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SwishJit()
#           (conv_expand): Conv2d(100, 1200, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pwl): MixedConv2d(
#           (0): Conv2d(600, 100, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(600, 100, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn3): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SwishJit()
#         (conv_dw): MixedConv2d(
#           (0): Conv2d(300, 300, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=300, bias=False)
#           (1): Conv2d(300, 300, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=300, bias=False)
#           (2): Conv2d(300, 300, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=300, bias=False)
#           (3): Conv2d(300, 300, kernel_size=(9, 9), stride=(1, 1), padding=(4, 4), groups=300, bias=False)
#         )
#         (bn2): BatchNorm2d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SwishJit()
#         (se): SqueezeExcite(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (conv_reduce): Conv2d(1200, 100, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SwishJit()
#           (conv_expand): Conv2d(100, 1200, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pwl): MixedConv2d(
#           (0): Conv2d(600, 100, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): Conv2d(600, 100, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn3): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (conv_head): Conv2d(200, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn2): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (act2): ReLU(inplace=True)
#   (global_pool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Linear(in_features=1536, out_features=1000, bias=True)
# )
# 1536
# 1030
# ==> Initialising sampler
# =====> Loading indices
# =====> Loading samples
# =====> Assigning weights
# 100%|████████████████████████████████████| 2089/2089 [00:00<00:00, 49317.81it/s]
# ==> Training model
# =====> Initial test
# 100%|███████████████████████████████████████████| 33/33 [01:49<00:00,  3.32s/it]
# Rock-auc - 0.5298822873371256
# [288. 185. 576.] - count of true targets
# [768.   0. 159.] - count of predicted targets
# Test set: Average loss: 0.0218, F1: 0.2491, Test ROC-AUC: 0.530
#
# cuda:0
# wandb 0
# 100%|███████████████████████████████████████████| 66/66 [04:42<00:00,  4.29s/it]
# [720. 774. 695.] - count of true targets
# [521. 609. 477.] - count of predicted targets
# Train Epoch: 0 	Loss: 0.018125  My F1: 0.5156, AP: 0.6099, ROC-AUC: 0.738
# 100%|███████████████████████████████████████████| 33/33 [01:46<00:00,  3.23s/it]
# Rock-auc - 0.8358282486826504
# [301. 209. 548.] - count of true targets
# [214. 121. 390.] - count of predicted targets
# Test set: Average loss: 0.0157, F1: 0.6055, Test ROC-AUC: 0.836
#
# cuda:0
# wandb 0
# 100%|███████████████████████████████████████████| 66/66 [04:45<00:00,  4.33s/it]
# [700. 780. 734.] - count of true targets
# [518. 641. 561.] - count of predicted targets
# Train Epoch: 1 	Loss: 0.015642  My F1: 0.6148, AP: 0.7032, ROC-AUC: 0.814
# 100%|███████████████████████████████████████████| 33/33 [01:54<00:00,  3.47s/it]
# Rock-auc - 0.8461333341871402
# [313. 199. 560.] - count of true targets
# [222. 102. 552.] - count of predicted targets
# Test set: Average loss: 0.0148, F1: 0.6234, Test ROC-AUC: 0.846
#
# cuda:0
# wandb 0
# 100%|███████████████████████████████████████████| 66/66 [04:49<00:00,  4.39s/it]
# [775. 790. 674.] - count of true targets
# [655. 673. 561.] - count of predicted targets
# Train Epoch: 2 	Loss: 0.015796  My F1: 0.6345, AP: 0.6936, ROC-AUC: 0.812
# 100%|███████████████████████████████████████████| 33/33 [01:58<00:00,  3.60s/it]
# Rock-auc - 0.8015991381613498
# [317. 194. 563.] - count of true targets
# [361. 148. 347.] - count of predicted targets
# Test set: Average loss: 0.0159, F1: 0.5695, Test ROC-AUC: 0.802
#
# cuda:0
# wandb 0
# 100%|███████████████████████████████████████████| 66/66 [04:15<00:00,  3.88s/it]
# [769. 778. 693.] - count of true targets
# [607. 680. 516.] - count of predicted targets
# Train Epoch: 3 	Loss: 0.015390  My F1: 0.6380, AP: 0.7174, ROC-AUC: 0.819
# 100%|███████████████████████████████████████████| 33/33 [01:44<00:00,  3.15s/it]
# Rock-auc - 0.8077414401644717
# [302. 210. 571.] - count of true targets
# [309.  94. 402.] - count of predicted targets
# Test set: Average loss: 0.0153, F1: 0.5615, Test ROC-AUC: 0.808
#
# cuda:0
# wandb 0
# 100%|███████████████████████████████████████████| 66/66 [04:29<00:00,  4.09s/it]
# [741. 785. 693.] - count of true targets
# [605. 678. 528.] - count of predicted targets
# Train Epoch: 4 	Loss: 0.014946  My F1: 0.6613, AP: 0.7373, ROC-AUC: 0.834
# 100%|███████████████████████████████████████████| 33/33 [01:45<00:00,  3.21s/it]
# Rock-auc - 0.8436101672395995
# [327. 203. 540.] - count of true targets
# [340. 102. 397.] - count of predicted targets
# Test set: Average loss: 0.0146, F1: 0.6044, Test ROC-AUC: 0.844
#
# cuda:0
# wandb 0
# 100%|███████████████████████████████████████████| 66/66 [04:15<00:00,  3.88s/it]
# [741. 783. 686.] - count of true targets
# [626. 681. 589.] - count of predicted targets
# Train Epoch: 5 	Loss: 0.015086  My F1: 0.6566, AP: 0.7107, ROC-AUC: 0.832
# 100%|███████████████████████████████████████████| 33/33 [01:52<00:00,  3.42s/it]
# Rock-auc - 0.8240261020608584
# [332. 201. 567.] - count of true targets
# [407. 119. 367.] - count of predicted targets
# Test set: Average loss: 0.0159, F1: 0.6242, Test ROC-AUC: 0.824
#
# cuda:0
# wandb 0
# 100%|███████████████████████████████████████████| 66/66 [04:26<00:00,  4.04s/it]
# [748. 782. 694.] - count of true targets
# [609. 672. 573.] - count of predicted targets
# Train Epoch: 6 	Loss: 0.014848  My F1: 0.6490, AP: 0.7137, ROC-AUC: 0.832
# 100%|███████████████████████████████████████████| 33/33 [01:55<00:00,  3.51s/it]
# Rock-auc - 0.8563502636746158
# [328. 183. 596.] - count of true targets
# [513.  81. 429.] - count of predicted targets
# Test set: Average loss: 0.0148, F1: 0.6148, Test ROC-AUC: 0.856
#
# cuda:0
# wandb 0
# 100%|███████████████████████████████████████████| 66/66 [04:10<00:00,  3.80s/it]
# [719. 788. 737.] - count of true targets
# [561. 704. 642.] - count of predicted targets
# Train Epoch: 7 	Loss: 0.014772  My F1: 0.6517, AP: 0.7090, ROC-AUC: 0.839
#  48%|████████████████████▊                      | 16/33 [01:27<00:44,  2.64s/it]

# %%
# !python -W ignore ../src/train.py --tags "3#drop0.2" --base "resnet18" --image_size 128 --lr 1e-3 --epochs 200 \
--batch_size 8 --wandb 0

# %%
# !python -W ignore ../src/train.py --tags "1#drop0.2" --base "mixnet_s" --image_size 224 --wandb 1 \
          --batch_size 24 --inp_size 1536

# %%
# !python -W ignore ../src/train.py --tags "1#drop0.2#" --base "mnasnet_a1" --image_size 224 --wandb 1
